# %% [markdown]
# <a href="https://colab.research.google.com/github/wanickols01/ConwayLanguage/blob/main/Linear_Regression_Exercise_1a_Food_Truck.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Assignment 1

# %% [markdown]
# ##Google Drive and receiving Data

# %%
# Import necessary libraries
from google.colab import drive
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# Mount Google Drive
try:
    drive.mount("/content/drive")
except:
    print("Google Drive already mounted")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load the data into a Pandas DataFrame
filename = "/content/drive/My Drive/Colab Notebooks/Data/ex1data1.txt" ##### IMPORTANT #####, This is a file path that is unique to my google drive. This will need to change to wherever you are keeping ex1data2
col_names = ["Population", "Profit"]
data = pd.read_csv(filename, header=None, names=col_names)

# %% [markdown]
# ##Generating a Linear Regression

# %%
# Perform linear regression to obtain the line of best fit
slope, intercept, r_value, p_value, std_err = stats.linregress(data["Population"], data["Profit"])

# Calculate the predicted values for x
x = data["Population"]
y = slope * x + intercept

# %%
#Style
sns.set_style("darkgrid")
plt.figure(figsize=(12, 8)) #sets size in inch

# Fit a linear regression model to the data
sns.regplot(x='Population', y='Profit', data=data, color='red', ci=None, scatter_kws={'s':30}, label='Regression Line')
sns.scatterplot(x='Population', y='Profit', data=data,  color='blue', s=30, label='points')

# Show the plot
plt.show()

# %%
def predict_profit(population, slope, intercept):
    return slope * population + intercept

population = 12
predicted_profit = predict_profit(population, slope, intercept)

#Style
sns.set_style("darkgrid")
plt.figure(figsize=(12, 8)) #sets size in inch

# Plot the regression line
#sns.regplot(x="Population", y="Profit", data=data, ci=None, color='blue')
sns.regplot(x='Population', y='Profit', data=data, ci=None, color='blue', label='Original')

# Predict the profit for a population of a set value
pred_pop = 12
pred_profit = (pred_pop * slope) + intercept

# Plot the predicted point on top of the line
plt.scatter(pred_pop, pred_profit, color='green', s=100, label='Predicted Value')

# Show the plot
plt.legend()
plt.show()
